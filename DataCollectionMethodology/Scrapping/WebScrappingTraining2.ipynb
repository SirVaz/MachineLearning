# %%
import requests
import json

response = requests.get('https://api.fbi.gov/wanted/v1/list', params={
    'field_offices': 'miami'
})
data = json.loads(response.content)
print(data)
print(data['total'])
print(data['items'][0]['title'])
# Out:
# {'total': 33, 'items': [{'files': [{'url': 'https://www.fbi.gov/wanted/kidnap/robert-craig-ehlert/download.pdf', 'name': 'English'}, {'url': 'https://www.fbi.gov/wanted/kidnap/robert-craig-ehlert/elhert-spanish-4-22-2021.pdf/@@download/file/Elhert Spanish 4-22-2021.pdf', 'name': 'EN ESPAÑOL'}], 'age_range': None, 'uid': '4c1eb3132d364884be9252f0091088d6', 'weight': '180 to 200 pounds', 'occupations': ['Retired - Finance'], 'field_offices': ['miami'], 'locations': None, 'reward_text': None, 'hair': 'brown', 'ncic': None, 'dates_of_birth_used': ['February 16, 1942'], 'caution': None, 'nationality': None, 'age_min': None, 'age_max': None, 'scars_and_marks': None, 'subjects': ['Missing Persons'], 'aliases': None, 'race_raw': 'White', 'suspects': None, 'publication': '2021-04-07T14:30:00', 'title': 'ROBERT CRAIG EHLERT', 'coordinates': [], 'hair_raw': 'Brown and gray', 'languages': None, 'complexion': None, 'build': None, 'details': '<p>In June of 2013, Robert “Bob”\xa0Ehlert\xa0went missing in Panama.\xa0Ehlert\xa0was living in Panama at the time and was planning on sailing on his yacht around the world. He disappeared before the trip and has not been seen or heard from since.</p>', 'status': 'na', 'legat_names': None, 'eyes': 'green', 'person_classification': 'Main', 'description': 'June 2013\r\nPanama', 'images': [{'large': 'https://www.fbi.gov/wanted/kidnap/robert-craig-ehlert/@@images/image/large', 'caption': 'Photograph taken in 2013', 'thumb': 'https://www.fbi.gov/wanted/kidnap/robert-craig-ehlert/@@images/image/thumb', 'original': 'https://www.fbi.gov/wanted/kidnap/robert-craig-ehlert/@@images/image'}], 'possible_countries': None, 'weight_min': 180, 'additional_information': None, 'remarks': '<p>Ehlert is commonly known by his nickname "Bob" and\xa0has previously resided in Harris, Minnesota.</p>', 'path': '/wanted/kidnap/robert-craig-ehlert', 'sex': 'Male', 'eyes_raw': 'Green', 'weight_max': 200, 'reward_min': 0, 'url': 'https://www.fbi.gov/wanted/kidnap/robert-craig-ehlert', 'possible_states': None, 'modified': '2021-04-22T15:19:51+00:00', 'reward_max': 0, 'race': 'white', 'height_max': 70, 'place_of_birth': 'Minnesota', 'height_min': 70, 'warning_message': None, '@id': 'https://api.fbi.gov/@wanted-person/4c1eb3132d364884be9252f0091088d6'}, {'eyes': 'brown', 'sex': 'Male', 'age_max': 52, 'url': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil', 'ncic': None, 'path': '/wanted/seeking-info/ali-hage-zaki-jalil', 'locations': None, 'weight_min': 200, 'place_of_birth': None, 'reward_min': 0, 'subjects': ['Seeking Information'], 'additional_information': None, 'reward_max': 0, 'languages': None, 'uid': '052b0a948f4344c9b2864e53f1b0c97f', 'eyes_raw': 'Brown', 'height_max': 70, 'nationality': None, 'age_range': 'Approximately 52 years old', 'height_min': 70, 'aliases': None, 'reward_text': None, 'possible_countries': None, 'description': 'Bombing of Alas Chiricanas Airlines Flight 00901\r\nJuly 19, 1994\r\nPanama', 'caution': None, 'weight_max': 200, 'legat_names': None, 'race': None, 'modified': '2020-09-04T15:29:11+00:00', 'publication': '2020-07-28T11:03:00', 'weight': 'Approximately 200 pounds', 'status': 'na', 'possible_states': None, 'scars_and_marks': None, 'images': [{'thumb': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/@@images/image/thumb', 'original': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/@@images/image', 'caption': None, 'large': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/@@images/image/large'}, {'thumb': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil_with_venezuelan_military-2014.jpg/@@images/image/thumb', 'original': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil_with_venezuelan_military-2014.jpg', 'caption': '', 'large': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki-jalil/jalil_with_venezuelan_military-2014.jpg/@@images/image/large'}, {'thumb': 'https://www.fbi.gov/wanted/seeking-info/ali-hage-zaki ...
# 33
# ROBERT CRAIG EHLERT
